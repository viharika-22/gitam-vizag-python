# %% [markdown]
# # Mini Project on IPL Data-set
# - Probelm Statement
#   - Display the count of matches based on the year wise¶
#      -Description of the problem

# %%
import pandas as pd
filepath='datafiles/Match.csv'
def readcsvdata(filepath):
    return pd.read_csv(filepath)
df=readcsvdata(filepath)

# %%
print(df)
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
c=df['Season_Year'].tolist()
a=c.count(2008)
b=c.count(2009)
d=c.count(2010)
e=c.count(2011)
sum1=a+b+d+e
print(a)
print(b)
print(d)
print(e)
print (c)
# Out:
# 58
# 57
# 60
# 73
# ...

# %%
 b=df.groupby('Season_Year')['Season_Year'].count()
final={' MATCHES':b}
final=pd.DataFrame(final)
final
#grouping of season years with the count of matchs in that perticular year
# Out:
#               MATCHES
# Season_Year
# 2008               58
# 2009               57
# 2010               60
# 2011               73
# 2012               74
# 2013               76
# 2014               60
# 2015               59
# 2016               60
# 2017               60

# %%
len(df)
# Out:
# 637

# %%
 import numpy as np
def unique(list1):
    x= np.array(list1)
    print(np.unique(list1))
a=df['Team1'].tolist()
unique(a)
# Out:
# ['Chennai Super Kings' 'Deccan Chargers' 'Delhi Daredevils'
#  'Gujarat Lions' 'Kings XI Punjab' 'Kochi Tuskers Kerala'
#  'Kolkata Knight Riders' 'Mumbai Indians' 'Pune Warriors'
#  'Rajasthan Royals' 'Rising Pune Supergiants'
#  'Royal Challengers Bangalore' 'Sunrisers Hyderabad']

# %%
import matplotlib.pyplot as plt
c=df[df['Season_Year']==2011]
d=c['match_winner'].value_counts()
pd.DataFrame(d)
print(d)
print()
teams=[]
teams=d.index.tolist()
plt.barh(teams,d,color="blue")
#ploted a horizontal bar graph by filtering based on the season year equal to 2011 and and finding match winners counts
# Out:
# Chennai Super Kings            11
# Royal Challengers Bangalore    10
# Mumbai Indians                 10
# Kolkata Knight Riders           8
# Kings XI Punjab                 7
# Kochi Tuskers Kerala            6
# Deccan Chargers                 6
# Rajasthan Royals                6
# Delhi Daredevils                4
# Pune Warriors                   4
# Name: match_winner, dtype: int64
# <BarContainer object of 10 artists>

# %%
li1=[8,7,6,7,7,7,8,7,7,8]
li2=[Chennai Super Kings,Deccan Chargers,Delhi Daredevils,Kings XI Punjab,Kochi Tuskers Kerala ,Kolkata Knight Riders ,Mumbai Indians,Pune Warriors, Rajasthan Royals,Royal Challengers Bangalore]
# Out:
#   File "<ipython-input-37-9883280c032d>", line 2
#     li2=[Chennai Super Kings,Deccan Chargers,Delhi Daredevils,Kings XI Punjab,Kochi Tuskers Kerala ,Kolkata Knight Riders ,Mumbai Indians,Pune Warriors, Rajasthan Royals,Royal Challengers Bangalore    ]
#                      ^
# SyntaxError: invalid syntax

# %%
k=df[df['City_Name']=='Hyderabad']
r=c['ManOfMach'].value_counts()
r
final={'ManOfMach':r}
final=pd.DataFrame(final)
final
# Out:
#                   ManOfMach
# CH Gayle                  6
# MEK Hussey                3
# M Vijay                   2
# A Mishra                  2
# V Kohli                   2
# SL Malinga                2
# SK Warne                  2
# BB McCullum               2
# V Sehwag                  2
# BJ Hodge                  2
# R Sharma                  2
# YK Pathan                 2
# Iqbal Abdulla             2
# PC Valthaty               2
# MM Patel                  2
# MS Dhoni                  1
# AC Gilchrist              1
# S Sohal                   1
# LRPL Taylor               1
# JH Kallis                 1
# DE Bollinger              1
# SR Watson                 1
# AT Rayudu                 1
# MR Marsh                  1
# SK Raina                  1
# G Gambhir                 1
# KD Karthik                1
# I Sharma                  1
# P Parameswaran            1
# SB Wagh                   1
# S Aravind                 1
# SR Tendulkar              1
# ...
